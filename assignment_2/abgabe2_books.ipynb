# %%
import os
from surprise import Dataset, Reader, SlopeOne
from surprise.model_selection import train_test_split

# path to dataset file
file_path = os.path.expanduser("BX-Book-Ratings.csv")

print(file_path)

# As we're loading a custom dataset, we need to define a reader. In the
# movielens-100k dataset, each line has the following format:
# 'user item rating timestamp', separated by '\t' characters.
reader = Reader(line_format="user item rating", sep=";", skip_lines=1)

data = Dataset.load_from_file('./BX-Book-Ratings.csv', reader)

trainset, testset = train_test_split(data, test_size=.20)

algo = SlopeOne()
algo.fit(trainset)
predictions = algo.test(testset)
# Out:
# BX-Book-Ratings.csv

# %%
searchedUserId = testset[0][0]

def findGoodItemsTask(predictions, userId=1):
    print(predictions)
    allRecomandations = []

    for uid, iid, true_r, est, _ in predictions:
        if uid == userId:
            allRecomandations.append((iid, est, true_r))

    return sorted(allRecomandations, key=lambda recommendation: recommendation[1], reverse=True)

recommendations = findGoodItemsTask(predictions, userId=searchedUserId)
# Out:
# [Prediction(uid='1548', iid='006093395X', r_ui=6.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='278095', iid='0553210416', r_ui=7.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='277203', iid='0717287106', r_ui=8.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='278698', iid='0440241073', r_ui=10.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='2033', iid='1891400495', r_ui=10.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='276786', iid='8466300821', r_ui=6.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='277203', iid='0689847564', r_ui=8.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='1172', iid='3453151933', r_ui=10.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='276964', iid='0886774802', r_ui=8.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='278418', iid='0373074646', r_ui=6.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='183', iid='972370403X', r_ui=8.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='2033', iid='0886777127', r_ui=8.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='460', iid='9770390107900', r_ui=8.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='1025', iid='0749720182', r_ui=7.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='242', iid='342311360X', r_ui=10.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='254', iid='0060502320', r_ui=7.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='276847', iid='3442446414', r_ui=10.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='278418', iid='038097391X', r_ui=5.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='278540', iid='0060937742', r_ui=1.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='277203', iid='059044297X', r_ui=9.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='278194', iid='0671683993', r_ui=8.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='2110', iid='059035342X', r_ui=10.0, est=5, details={'was_impossible': False}), Prediction(uid='183', iid='9726081378', r_ui=9.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='2043', iid='0345421825', r_ui=10.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='278522', iid='0515124060', r_ui=7.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='276936', iid='3596122279', r_ui=5.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='853', iid='034545829X', r_ui=9.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='277801', iid='0380750260', r_ui=7.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='638', iid='0316693006', r_ui=10.0, est=5, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}), Prediction(uid='1903', iid='0879804211', r_ui=1.0, est=5, details={'was_impossible': True,  ...
